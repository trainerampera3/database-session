# %%
from pathlib import Path

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data_folder = Path(".")

employees_path = data_folder / "employees.csv"
departments_path = data_folder / "departments.csv"
payroll_path=data_folder / "payroll.csv"
attendance_path=data_folder/"attendance.csv"
performance_path=data_folder/"performance_reviews.csv"

# %%
employees = pd.read_csv(employees_path)

# %%
departments=pd.read_csv(departments_path)

# %%
payroll=pd.read_csv(payroll_path)

# %%
payroll.shape
# Out:
# (60000, 5)

# %%
performance=pd.read_csv(attendance_path)

# %%
performance=pd.read_csv(performance_path)

# %%
performance.shape
# Out:
# (10000, 4)

# %%
employees.shape
# Out:
# (10100, 9)

# %%
departments.shape
# Out:
# (20, 3)

# %%
payroll.shape
# Out:
# (60000, 5)

# %%
attendance.shape
# Out:
# (10000, 4)

# %%
performance.shape
# Out:
# (50000, 5)

# %%
employees.head()
# Out:
#    employee_id employee_code gender   age  department_id job_title  \
# 0            1      EMP00001      M  29.0           13.0    Intern
# 1            2      EMP00002      M  57.0            2.0        QA
# 2            3      EMP00003      F  46.0            3.0  Engineer
# 3            4      EMP00004   Male  56.0            4.0  Engineer
# 4            5      EMP00005   Male  34.0            2.0        QA
#
#     join_date  salary          email
# 0  2023-01-15  350000  emp1@mail.com
# 1  15/02/2024  350000  emp2@mail.com
# 2  2023-01-15  -10000            NaN
# 3         NaN  350000            NaN
# 4  15/02/2024  800000            NaN

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_id    10100 non-null  int64
#  1   employee_code  10100 non-null  object
#  2   gender         8397 non-null   object
#  3   age            9856 non-null   float64
#  4   department_id  9666 non-null   float64
#  5   job_title      10100 non-null  object
#  6   join_date      6135 non-null   object
#  7   salary         8444 non-null   object
#  8   email          5093 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 710.3+ KB

# %%
employees.describe()
# Out:
#         employee_id          age  department_id
# count  10100.000000  9856.000000    9666.000000
# mean    4999.962277    40.421469      14.824643
# std     2886.828406    16.141985      19.917548
# min        1.000000    -2.000000       1.000000
# 25%     2498.750000    29.000000       6.000000
# 50%     4998.500000    40.000000      11.000000
# 75%     7501.250000    51.000000      16.000000
# max    10000.000000    99.000000      99.000000

# %%
employees.isnull().sum()
# Out:
# employee_id         0
# employee_code       0
# gender           1703
# age               244
# department_id     434
# job_title           0
# join_date        3965
# salary           1656
# email            5007
# dtype: int64

# %%
employees.duplicated().sum()
# Out:
# 100

# %%
attendance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    10000 non-null  int64
#  1   employee_id  9999 non-null   float64
#  2   rating       8763 non-null   float64
#  3   remarks      8407 non-null   object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 312.6+ KB

# %%
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_id    20 non-null     int64
#  1   department_name  20 non-null     object
#  2   location         20 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 608.0+ bytes

# %%
employees.head()
# Out:
#    employee_id employee_code gender   age  department_id job_title  \
# 0            1      EMP00001      M  29.0           13.0    Intern
# 1            2      EMP00002      M  57.0            2.0        QA
# 2            3      EMP00003      F  46.0            3.0  Engineer
# 3            4      EMP00004   Male  56.0            4.0  Engineer
# 4            5      EMP00005   Male  34.0            2.0        QA
#
#     join_date  salary          email
# 0  2023-01-15  350000  emp1@mail.com
# 1  15/02/2024  350000  emp2@mail.com
# 2  2023-01-15  -10000            NaN
# 3         NaN  350000            NaN
# 4  15/02/2024  800000            NaN

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_id    10100 non-null  int64
#  1   employee_code  10100 non-null  object
#  2   gender         8397 non-null   object
#  3   age            9856 non-null   float64
#  4   department_id  9666 non-null   float64
#  5   job_title      10100 non-null  object
#  6   join_date      6135 non-null   object
#  7   salary         8444 non-null   object
#  8   email          5093 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 710.3+ KB

# %%
employees.isnull().sum()
# Out:
# employee_id         0
# employee_code       0
# gender           1703
# age               244
# department_id     434
# job_title           0
# join_date        3965
# salary           1656
# email            5007
# dtype: int64

# %%
(employees=="").sum()
# Out:
# employee_id      0
# employee_code    0
# gender           0
# age              0
# department_id    0
# job_title        0
# join_date        0
# salary           0
# email            0
# dtype: int64

# %%
(employees.apply(lambda x : x.astype(str).str.strip()=="")).sum()
# Out:
# employee_id      0
# employee_code    0
# gender           0
# age              0
# department_id    0
# job_title        0
# join_date        0
# salary           0
# email            0
# dtype: int64

# %%
employees.duplicated().sum()
# Out:
# 100

# %%
employees["employee_id"].duplicated().sum()
# Out:
# 100

# %%
employees[pd.to_numeric(employees["age"],errors="coerce")<18]
# Out:
#        employee_id employee_code  gender  age  department_id job_title  \
# 58              59      EMP00059  Female -2.0           10.0   Analyst
# 259            260      EMP00260  Female -2.0           99.0    Intern
# 302            303      EMP00303    Male -2.0            6.0   Analyst
# 309            310      EMP00310     NaN -2.0            4.0   Analyst
# 360            361      EMP00361    male -2.0           99.0  Engineer
# ...            ...           ...     ...  ...            ...       ...
# 9799          9800      EMP09800       F -2.0            6.0  Engineer
# 9884          9885      EMP09885    male -2.0            8.0   Manager
# 9977          9978      EMP09978    Male -2.0           15.0        HR
# 10046         3728      EMP03728     NaN -2.0           19.0  Engineer
# 10058          807      EMP00807    male -2.0            8.0  Engineer
#
#         join_date  salary            email
# 58     15/02/2024   6 LPA              NaN
# ...

# %%
employees["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      1722
# male      1704
# NaN       1703
# Female    1684
# F         1661
# M         1626
# Name: count, dtype: int64

# %%
employees["join_date"].value_counts(dropna=False).head(20)
# Out:
# join_date
# NaN           3965
# 2023-01-15    2097
# 2025-07-01    2029
# 15/02/2024    2009
# Name: count, dtype: int64

# %%
employees["salary"].value_counts(dropna=False).head(20)
# Out:
# salary
# -10000    1764
# 800000    1686
# 350000    1673
# 6 LPA     1664
# 500000    1657
# NaN       1656
# Name: count, dtype: int64

# %%
clean_employees=employees.copy()

# %%
clean_employees.columns = (
    clean_employees.columns
    .str.replace('___', '_')
    .str.strip('_')
    .str.lower()
)

# %%
clean_employees.columns
# Out:
# Index(['employee__id', 'employee__code', 'gender', 'age', 'department__id',
#        'job__title', 'join__date', 'salary', 'email'],
#       dtype='object')

# %%
clean_employees=clean_employees.replace(r'^\s*$',np.nan,regex=True)

# %%
clean_employees.isna().sum()
# Out:
# employee__id         0
# employee__code       0
# gender            1703
# age                244
# department__id     434
# job__title           0
# join__date        3965
# salary            1656
# email             5007
# dtype: int64

# %%
clean_employees=clean_employees.drop_duplicates()

# %%
clean_employees.duplicated().sum()
# Out:
# 0

# %%
clean_employees["gender"]=(
    clean_employees["gender"]
    .astype("string")
    .str.strip()
    .str.lower()
)

# %%
clean_employees["gender"]=clean_employees["gender"].replace({
    "m":"Male",
    "male":"Male",
    "f":"Female",
    "female":"Female"
})

# %%
clean_employees["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      5001
# Female    3304
# <NA>      1695
# Name: count, dtype: Int64

# %%
clean_employees["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      5001
# Female    3304
# <NA>      1695
# Name: count, dtype: Int64

# %%
clean_employees["age"]=pd.to_numeric(
    clean_employees["age"],
    errors="coerce"
)

# %%
import numpy as np

# %%
clean_employees.loc[
(clean_employees["age"]<18)|(clean_employees["age"]>18),"age"]=np.nanclean_employees.loc[
(clean_employees["age"]<18)|(clean_employees["age"]>18),"age"]=np.nan

# %%
clean_employees["department__id"] = pd.to_numeric(
    clean_employees["department__id"],
    errors="coerce"
)

# %%
clean_employees["join__date"]=pd.to_datetime(
    clean_employees["join__date"],
    errors="coerce",
    dayfirst=True
)
# Out:
# /tmp/ipykernel_98481/4144105081.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   clean_employees["join__date"]=pd.to_datetime(

# %%
clean_employees["join__date"].isna().sum()
# Out:
# 5917

# %%
clean_employees["salary"] = clean_employees["salary"].astype("string")

# %%
clean_employees["salary"] = (
    clean_employees["salary"]
    .str.replace("₹", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.strip()
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[134], line 2
#       1 clean_employees["salary"] = (
# ----> 2     clean_employees["salary"]
#       3     .str.replace("₹", "", regex=False)
#       4     .str.replace(",", "", regex=False)
#       5     .str.strip()
#       6 )
#
# File /snap/python-ai-toolkit/51/lib/python3.8/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File /snap/python-ai-toolkit/51/lib/python3.8/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
numeric_series = pd.to_numeric(cleaned_text, errors="coerce")


lpa_mask = clean_employees["salary"].str.contains("LPA", case=False, na=False)


numeric_series[lpa_mask] = numeric_series[lpa_mask] * 100000


clean_employees["salary"] = numeric_series


print(clean_employees["salary"].dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[136], line 4
#       1 numeric_series = pd.to_numeric(cleaned_text, errors="coerce")
# ----> 4 lpa_mask = clean_employees["salary"].str.contains("LPA", case=False, na=False)
#       7 numeric_series[lpa_mask] = numeric_series[lpa_mask] * 100000
#      10 clean_employees["salary"] = numeric_series
#
# File /snap/python-ai-toolkit/51/lib/python3.8/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# ...

# %%
print(clean_employees["salary"].head())
print("Data Type:", clean_employees["salary"].dtype)
# Out:
# 0    350000
# 1    350000
# 2    -10000
# 3    350000
# 4    800000
# Name: salary, dtype: Int64
# Data Type: Int64

# %%
clean_employees.loc[clean_employees["salary"]<0 , "salary"]=np.nan

# %%
clean_employees["email"]=(
    clean_employees["email"]
    .astype("string")
    .str.strip()
    .str.lower()
)

# %%
email_pattern=r"^[^@\s]+@[^@\s]+\.[^@\s]+$"

# %%
invalid_email = ~(clean_employees["email"].str.match(
    email_pattern,
    na=False
))

# %%
clean_employees.loc[invalid_email,"email"]=np.nan

# %%
clean_employees["age"].isna().sum()
# Out:
# 10000

# %%
age_median=clean_employees["age"].median()
print(age_median)
# Out:
# 40.0

# %%
clean_employees["age"]=clean_employees["age"].fillna(age_median)

# %%
clean_employees["age"].isna().sum()
# Out:
# 0

# %%
clean_employees["age"] = employees["age"]

# %%
clean_employees.loc[
(clean_employees["age"]<18)|(clean_employees["age"]>65),"age"]=np.nan

# %%
clean_employees["salary"] = (
    clean_employees
    .groupby("department__id")["salary"]
    .transform(lambda x: x.fillna(x.median()))
)

overall_salary_median = clean_employees["salary"].median()
clean_employees["salary"] = clean_employees["salary"].fillna(overall_salary_median)

# %%
print("Remaining NaN values in salary:", clean_employees["salary"].isna().sum())
# Out:
# Remaining NaN values in salary: 0

# %%
clean_employees["gender"]=clean_employees["gender"].fillna("Unknow")

# %%
clean_employees["gender"].value_counts()
# Out:
# gender
# Male      5001
# Female    3304
# Unknow    1695
# Name: count, dtype: Int64

# %%
clean_employees["email"].isna().sum()
# Out:
# 7523

# %%
clean_employees.isna().sum()
# Out:
# employee__id         0
# employee__code       0
# gender               0
# age                  0
# department__id     430
# job__title           0
# join__date        5917
# salary               0
# email             7523
# dtype: int64

# %%
clean_employees.duplicated().sum()
# Out:
# 0

# %%
clean_employees["age"].describe()
# Out:
# count    10000.00000
# mean        39.98050
# std         11.39453
# min         20.00000
# 25%         31.00000
# 50%         40.00000
# 75%         49.00000
# max         60.00000
# Name: age, dtype: float64

# %%
clean_employees["salary"].describe()
# Out:
# count          10000.0
# mean          564215.0
# std      133618.745586
# min           350000.0
# 25%           500000.0
# 50%           600000.0
# 75%           600000.0
# max           800000.0
# Name: salary, dtype: Float64

# %%
clean_employees["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      5001
# Female    3304
# Unknow    1695
# Name: count, dtype: Int64

# %%
departments=pd.read_csv("departments.csv")

# %%
departments.head()
# Out:
#    department_id department_name   location
# 0              1    Department_1     Mumbai
# 1              2    Department_2  Hyderabad
# 2              3    Department_3       Pune
# 3              4    Department_4       Pune
# 4              5    Department_5     Mumbai

# %%
valid_department_ids = departments["department_id"]

invalid_departments=clean_employees[
~clean_employees["department__id"].isin(valid_department_ids)]

invalid_departments
# Out:
#       employee__id employee__code  gender   age  department__id job__title  \
# 12              13       EMP00013  Female  22.0             NaN    Analyst
# 15              16       EMP00016  Unknow  56.0             NaN    Manager
# 21              22       EMP00022  Female  34.0             NaN   Engineer
# 25              26       EMP00026    Male  50.0            99.0    Manager
# 33              34       EMP00034    Male  39.0            99.0    Analyst
# ...            ...            ...     ...   ...             ...        ...
# 9983          9984       EMP09984    Male  20.0            99.0         HR
# 9987          9988       EMP09988  Female  42.0             NaN    Analyst
# 9989          9990       EMP09990    Male  24.0            99.0   Engineer
# 9992          9993       EMP09993    Male  58.0             NaN     Intern
# 9996          9997       EMP09997  Unknow  38.0            99.0    Manager
#
#      join__date  salary             email
# ...

# %%
invalid_departments
# Out:
#       employee__id employee__code  gender   age  department__id job__title  \
# 12              13       EMP00013  Female  22.0             NaN    Analyst
# 15              16       EMP00016  Unknow  56.0             NaN    Manager
# 21              22       EMP00022  Female  34.0             NaN   Engineer
# 25              26       EMP00026    Male  50.0            99.0    Manager
# 33              34       EMP00034    Male  39.0            99.0    Analyst
# ...            ...            ...     ...   ...             ...        ...
# 9983          9984       EMP09984    Male  20.0            99.0         HR
# 9987          9988       EMP09988  Female  42.0             NaN    Analyst
# 9989          9990       EMP09990    Male  24.0            99.0   Engineer
# 9992          9993       EMP09993    Male  58.0             NaN     Intern
# 9996          9997       EMP09997  Unknow  38.0            99.0    Manager
#
#      join__date  salary             email
# ...

# %%
clean_employees.to_csv("employees-cleaned.csv",index=False)
